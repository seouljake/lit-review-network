# %% [markdown]
# # import libraries

# %%
import pandas as pd

# %% [markdown]
# # import data

# %%
dat = pd.read_csv("../0 data_zotero/SK TW patronage.csv",encoding="UTF-8")

# %%
# rename column names - remove spaces between words in each column label
newcolumns = {item:item.replace(" ","") for item in dat.columns}
dat = dat.rename(columns = newcolumns)

# %%
dat
# Out:
#            Key        ItemType  PublicationYear  \
# 0     BSIPEGYH  journalArticle           1996.0
# 1     GIKD4D7E  journalArticle           1975.0
# 2     K2UZLPZA  journalArticle              NaN
# 3     C7PWED7G            book              NaN
# 4     AU4K4WWU         webpage              NaN
# ...        ...             ...              ...
# 1763  7P7R2TU3            book           2013.0
# 1764  VLDZDXJL            book           2010.0
# 1765  D3D7QJDZ            book           2022.0
# 1766  FS67CSQ9            book           2003.0
# 1767  S2U2VES9            book           2020.0
#
#                                Author  \
# 0                     Gould, Roger V.
# 1                       Braun, Rudolf
# 2                     Gould, Roger V.
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 1763            Harrison, Lawrence E.
# 1764  Hacker, Jacob S.; Pierson, Paul
# 1765                   Haber, Stephen
# 1766       Bonfiglioli, Angelo Maliki
# 1767    McConville, Mike; Marsh, Luke
#
#                                                   Title  \
# 0     Patron-Client Ties, State Centralization, and ...
# 1     Taxation, sociopolitical structure, and state-...
# 2     Political Networks and the Local/National Boun...
# 3     Relations into Rhetorics: Local Elite Structur...
# 4     Harper, R. Eugene. 1991. The Transformationf W...
# ...                                                 ...
# 1763  Jews, Confucians, and Protestants: Cultural Ca...
# 1764  Winner-Take-All Politics: How Washington Made ...
# 1765  How Latin America Fell Behind: Essays on the E...
# 1766  Empowering the Poor: Local Governance for Pove...
# 1767                  The Myth of Judicial Independence
#
#                                        PublicationTitle               ISBN  \
# 0                         American Journal of Sociology                NaN
# 1     The formation of national states in Western Eu...                NaN
# 2     Challenging Authority: The Historical Study of...                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN                NaN
# ...                                                 ...                ...
# 1763                                                NaN  978-1-4422-1963-2
# 1764                                                NaN  978-1-4165-8870-2
# 1765                                                NaN  978-1-5036-2250-0
# 1766                                                NaN  978-92-1-126158-5
# 1767                                                NaN  978-0-19-255527-4
#
#            ISSN  DOI                                                Url  ...  \
# 0     0002-9602  NaN               https://www.jstor.org/stable/2782630  ...
# 1           NaN  NaN                                                NaN  ...
# 2           NaN  NaN                                                NaN  ...
# 3           NaN  NaN  https://www.asanet.org/relations-rhetorics-loc...  ...
# 4           NaN  NaN  https://scholar.google.com/scholar?hl=ko&as_sd...  ...
# ...         ...  ...                                                ...  ...
# 1763        NaN  NaN                                                NaN  ...
# 1764        NaN  NaN                                                NaN  ...
# 1765        NaN  NaN                                                NaN  ...
# 1766        NaN  NaN                                                NaN  ...
# 1767        NaN  NaN                                                NaN  ...
#
#      ProgrammingLanguage Version System Code CodeNumber Section Session  \
# 0                    NaN     NaN    NaN  NaN        NaN     NaN     NaN
# 1                    NaN     NaN    NaN  NaN        NaN     NaN     NaN
# 2                    NaN     NaN    NaN  NaN        NaN     NaN     NaN
# 3                    NaN     NaN    NaN  NaN        NaN     NaN     NaN
# 4                    NaN     NaN    NaN  NaN        NaN     NaN     NaN
# ...                  ...     ...    ...  ...        ...     ...     ...
# 1763                 NaN     NaN    NaN  NaN        NaN     NaN     NaN
# 1764                 NaN     NaN    NaN  NaN        NaN     NaN     NaN
# 1765                 NaN     NaN    NaN  NaN        NaN     NaN     NaN
# 1766                 NaN     NaN    NaN  NaN        NaN     NaN     NaN
# 1767                 NaN     NaN    NaN  NaN        NaN     NaN     NaN
#
#      Committee  History  LegislativeBody
# 0          NaN      NaN              NaN
# 1          NaN      NaN              NaN
# 2          NaN      NaN              NaN
# 3          NaN      NaN              NaN
# 4          NaN      NaN              NaN
# ...        ...      ...              ...
# 1763       NaN      NaN              NaN
# 1764       NaN      NaN              NaN
# 1765       NaN      NaN              NaN
# 1766       NaN      NaN              NaN
# 1767       NaN      NaN              NaN
#
# [1768 rows x 87 columns]

# %% [markdown]
# # Author - Clean & Disambiguate

# %%
authorlist1 = dat[dat.Author.isnull() == False].Author.str.split(";").tolist()

# %%
#authorlist

# %%
# combine all authors into a single list
authorlist2 = []
for x in authorlist1:
    authorlist2+=x

# %%
# remove whitespace from author names and save as a list, using a list comprehension
authorlist2 = [item.strip() for item in authorlist2]

# %%
# remove duplicate names and sort alphabetically
length_with_duplicates = len(authorlist2)
print("With Duplicates:",length_with_duplicates)

authorlist2 = list(set(authorlist2))
authorlist2.sort()
length_without_duplicates = len(authorlist2)

print("Without Duplicates:",length_without_duplicates)

print("Duplicates:",length_with_duplicates-length_without_duplicates)
# Out:
# With Duplicates: 2197
# Without Duplicates: 1672
# Duplicates: 525

# %%
# look over the list for problems (e.g. duplicates with slighly different spellings, Jr, institutes which are not authors)
authorlist2
# Out:
# ['Abbott, Andrew',
#  'Abdullah, Taufik',
#  'Abelson, Robert P.',
#  'Abernethy, David B.',
#  'Abramovitch, Rona',
#  'Acemoglu, Daron',
#  'Adams, Julia',
#  'Adams, Richard E. W.',
#  'Adams, Simon',
#  'Adcock, F. E.',
#  'Adler, Patricia',
#  'Adler, Peter',
#  'Agevall, Ola',
#  'Agulhon, Maurice',
#  'Ahmad, Noor Sulastry Yurni',
#  'Ahmed, Mukhtar',
#  'Ahn, Chulhyun',
#  'Aiello, Luca Maria',
#  'Akita, George',
#  'Alberti, Leon Battista',
#  'Alcantara, Christopher',
#  'Alexander, John K.',
#  'Alford, John R.',
#  'Allee, William',
#  'Allern, Elin Haugsgjerd',
#  'Allison, Graham',
#  'Allport, Floyd Henry',
#  'Allum, Percy',
#  'Almond, Gabriel Abraham',
#  'Altmann, Michael',
#  'Amitai, Reuven',
#  'Ammon, Harry',
#  'Amsden, Alice Hoffenberg',
#  'An, Yong Heun',
#  "An-Na'im, Abdullahi",
#  'Anderson, Benedict',
#  'Anderson, Bo',
#  'Anderson, David',
#  'Anderson, Elijah',
#  'Anderson, Fred',
#  'Anderson, James',
#  'Anderson, Perry',
#  'Andrew, James',
#  'Ang, Yuen Yuen',
#  'Anspach, Mark R.',
#  'Apter, David Ernest',
#  'Argersinger, Peter',
#  'Arrow, Kenneth J.',
#  'Arthur, W. Brian',
#  'Asaba, Yuki',
#  'Ashford, Douglas Elliott',
#  'Ashley, Mary V.',
#  'Asquith, Pamela J.',
#  'Atiyah, Michael',
#  'Ausubel, D.P.',
#  'Axelrod, Robert',
#  'Ayal, Eliezer B.',
#  'Ayalon, David',
#  'Aylmer, Gerald Edward',
#  'Ayton, Andrew',
#  'Bach, Daniel C.',
#  'Bachrach, Bernard',
#  'Back, Kurt',
#  'Badahdah, Abdallah M.',
#  'Bae, Kyung-Jae',
#  'Bae, Sun-Kwang',
#  'Baenninger, Louise P.',
#  'Baillie, James Black',
#  'Baker, Donald',
#  'Baker, Hugh',
#  'Baker, Wayne E.',
#  'Bakhash, Shaul',
#  'Balazs, Etienne',
#  'Balazs, Stefan',
#  'Baldwin, Leland D.',
#  'Balogh, Brian',
#  'Banerjee, Abhijit V.',
#  'Banfield, Edward C.',
#  'Bank, World',
#  'Banner, James M.',
#  'Banton, Michael',
#  'Barber, Michael',
#  'Barchas, Patricia R.',
#  'Barkan, Joel D.',
#  'Barker, Judith',
#  'Barkey, Karen',
#  'Barkow, Jerome H.',
#  'Barner-Barry, Carol',
#  'Barnett, George A.',
#  'Barnett, L. Margaret',
#  'Barraclough, Geoffrey',
#  'Barth, Fredrik',
#  'Barzel, Yoram',
#  'Basham, Arthur Llewellyn',
#  'Bates, Nancy',
#  'Bates, Robert Hinrichs',
#  'Bateson, Paul Patrick Gordon',
#  'Battistella, Edwin L.',
#  'Bauman, Zygmunt',
#  'Baxandall, Michael',
#  'Baxter, Stephen Bartow',
#  'Bayart, Jean-François',
#  'Bayertz, Kurt',
#  'Beacham, Jeffery',
#  'Bean, John Malcolm William',
#  'Bearman, Peter',
#  'Becker, Carl Lotus',
#  'Becker, Gary Stanley',
#  'Becker, Robert A.',
#  'Beeler, John',
#  'Beik, William',
#  'Bell, Daniel',
#  'Bell, Michael Mayerfeld',
#  'Bell, Rudolph M.',
#  'Bellman, Richard E.',
#  'Bendix, Reinhard',
#  'Bennett, Robert',
#  'Bennett, Stuart',
#  'Berg, Nancy Eisenberg',
#  'Berger, Joseph',
#  'Berger, Suzanne',
#  'Bergmann, Eirikur',
#  'Berkey, Jonathan Porter',
#  'Berkowitz, Stephen',
#  'Berman, Carol',
#  'Berman, Harold Joseph',
#  'Bernard, H. Russell',
#  'Bernhardt, Kathryn',
#  'Bernstein, Irwin S.',
#  'Berry, Sara S.',
#  'Bertrand, Michel',
#  'Bhattacharya, Sukanto',
#  'Bian, Yanjie',
#  'Bicchieri, M. G.',
#  'Bienen, Henry',
#  'Billet, Bret L.',
#  'Black, Jeremy',
#  'Black, Robert',
#  'Blau, Peter M.',
#  'Bleck, Jaimie',
#  'Blume, Lawrence',
#  'Bo, Zhiyue',
#  'Bob-Milliar, George M.',
#  'Boettke, Peter J.',
#  'Bogaards, Matthijs',
#  'Boice, Robert',
#  'Boissevain, Jeremy',
#  'Boix, Carles',
#  'Bollig, Michael',
#  'Bolloten, Burnett',
#  'Bonfiglioli, Angelo Maliki',
#  'Bonomi, Patricia U.',
#  'Bonsteel Tachau, Mary K.',
#  'Boorman, Scott A.',
#  'Borrello, Mark E.',
#  'Bosco, Joseph',
#  'Boss, Michael',
#  'Bott, Elizabeth',
#  'Botto, Kathryn',
#  'Boucek, Françoise',
#  'Bourdieu, Pierre',
#  'Bourne, James',
#  'Bourne, John M.',
#  'Bovbjerg, Richard V.',
#  'Boyd, John Paul',
#  'Brackenridge, Hugh Henry',
#  'Bradley, Ralph Allan',
#  'Bradshaw, Karen M.',
#  'Brady, David',
#  'Brandtstädter, Susanne',
#  'Bratton, Michael',
#  'Braun, Rudolf',
#  'Breer, Paul E.',
#  'Breiger, Ronald L.',
#  'Breuggeman, Judith A.',
#  'Brewer, John',
#  'Bridges, Brian',
#  'Briggs, Asa',
#  'Bright, Charles',
#  'Brik, Anis Ben',
#  'Brodsgaard, Kjeld Erik',
#  'Brody, Charles J.',
#  'Brody, Richard A.',
#  'Brook, Timothy',
#  'Brown, David',
#  'Brown, Kerry',
#  'Brown, Lucy Trumbull',
#  'Browne, Eric C.',
#  'Browning, David',
#  'Brubaker, Rogers',
#  'Bruggeman, Jeroen',
#  'Brun, Diego Abente',
#  'Brunn, Stanley D.',
#  'Brunt, Peter Astbury',
#  'Brusco, Valeria',
#  'Brustein, William',
#  'Bryant, Kobe',
#  'Brynjolfsson, Erik',
#  'Brzezinski, Zbigniew',
#  'Brückner, Hannah',
#  'Buchanan, James M.',
#  'Buquet, Daniel',
#  'Burke, Edmund',
#  'Burke, Peter James',
#  'Burnham, Walter Dean',
#  'Bushnell, David',
#  'Butterfield, Herbert',
#  'Byrne, Richard W.',
#  'Bértoa, Fernando Casal',
#  "Cahill-O'Callaghan, Rachel",
#  'Cai, Yong',
#  'Caldwell, Bruce',
#  'Campbell, John L.',
#  'Cantor, Norman F.',
#  'Caridi, Ronald J.',
#  'Carlson, Chelsea',
#  'Carman, Harry James',
#  'Carneiro, Robert Leonard',
#  'Carothers, Thomas',
#  'Carpenter, Daniel',
#  'Carty, R. K.',
#  'Casper, Gerhard',
#  'Castañeda, Ernesto',
#  'Castellani, Francesca',
#  'Castellani, Lorenzo',
#  'Cathcart, Adam',
#  'Cavalli-Sforza, L. L.',
#  'Centeno, Miguel Angel',
#  'Ceron, Andrea',
#  'Cerulo, Karen A.',
#  'Cetina, Karin Knorr',
#  'Cha, Sujin',
#  'Cha, Victor D.',
#  'Chabal, Patrick',
#  'Chae, Haesook',
#  'Chambers, James',
#  'Chambers, William Nisbet',
#  'Champagne, Roger',
#  'Chandler, Alfred D.',
#  'Chandra, Kanchan',
#  'Chang, Chun',
#  'Chang, Kwang-Chih',
#  'Chang, Kwang-chih',
#  'Chang, Kyung-Sup',
#  'Chang, Paul Y.',
#  'Chang, Woo-young',
#  'Chang-jin, Kim',
#  'Chapman, Richard A.',
#  'Charles, Kurzman',
#  'Chase, Ivan D.',
#  'Chase, James S.',
#  'Chasquetti, Daniel',
#  'Cheeseman, Nic',
#  'Cheibub, José Antônio',
#  'Chen, Jianfu',
#  'Cheney, Dorothy L.',
#  'Cheng, Tun-jen',
#  'Cheol, Kim Yong',
#  'Cheol, Yu Myung',
#  'Chepko-Sade, B. Diane',
#  'Cherifi, Chantal',
#  'Cherifi, Hocine',
#  'Cherkaoui, Mohammed D.',
#  'Chesterman, Simon',
#  'Cheyette, Fredric L.',
#  'Chhibber, Pradeep',
#  'Chiaramonte, Alessandro',
#  'Chimpango, Boniface',
#  'Chitonge, Horman',
#  'Cho, Chung-Lae',
#  'Cho, Dong-Sung',
#  'Cho, Jinman',
#  'Cho, Kisuk',
#  'Cho, Youngho',
#  'Choi, Hwasick',
#  'Choi, Hyun-Soo',
#  'Choi, Jang Jip',
#  'Choi, Jun Young',
#  'Choi, Sukyoung',
#  'Choi, Young-chool',
#  'Choy, Hyon-Sook',
#  'Chu, Yun-han',
#  'Chubb, Judith',
#  'Chung, Doock-Kyou',
#  'Chung, Jae Ho',
#  'Claessen, Henri',
#  'Clark, Gregory',
#  'Clark, Tom S.',
#  'Clastres, Pierre',
#  'Clemens, Elisabeth S.',
#  'Cohen, Elizabeth G.',
#  'Cohen, Jared',
#  'Cole, Jennifer C.',
#  'Coleman, James',
#  'Collier, Paul',
#  'Collins, H.M.',
#  'Collins, Harry',
#  'Collins, Randall',
#  'Colodny, Robert G.',
#  'Conde, Roberto Cortés',
#  'Connell, William J.',
#  'Connolly, William E.',
#  'Connor, Robert E.',
#  'Constable, Julie L.',
#  'Cook, Philip J.',
#  'Cooke, Jacob E.',
#  'Cords, Marina',
#  'Corstange, Daniel',
#  'Cosmides, Leda',
#  'Costopoulos, Philip J.',
#  'Cotton, James',
#  'Coughlin, Richard',
#  'Cowen, Tyler',
#  'Cox, Gary',
#  'Craig, Gordon Alexander',
#  'Crane, Diana',
#  'Crawford, Charles',
#  'Creel, Herrlee Glessner',
#  'Creigh, Alfred',
#  'Crenson, Matthew A.',
#  'Creveld, Martin Van',
#  'Croissant, Aurel',
#  'Cronin, Carol L.',
#  'Cross, Rob',
#  'Cross, William P.',
#  'Crotty, William J.',
#  'Crouch, Harold',
#  'Crowley, James Buckley',
#  'Cruz-Aceves, Victor-David',
#  'Cummings, Scott',
#  'Cunliffe-Jones, Peter',
#  'Curtin, Philip DeArmond',
#  'Cîrlig, Samira',
#  'DAGGETT, David',
#  'Daddieh, Cyril K',
#  'Dahl, Robert A.',
#  'Daloz, Jean-Pascal',
#  'Dalrymple, Christina Ford',
#  'Dalton, Bronwen',
#  'Dalton, Melville',
#  'Dalton, Russell',
#  'Dalton, Toby',
#  'Dandeker, Christopher',
#  'Darcy, Robert',
#  'Dark',
#  'Darwin, Charles',
#  'Daston, Lorraine',
#  'David, Paul A.',
#  'Davis, James A.',
#  'Day, Tony',
#  'De La Vega, Garcilso',
#  'De Soto, Hernando',
#  'De Waal, Frans B. M.',
#  'Deag, John M.',
#  'Decker, Scott H.',
#  'Decker, Steve',
#  'Demchak, Chris C.',
#  'DenBoer, Gordon',
#  'Deng, Kent G.',
#  'Denoncourt, Janice',
#  'Devries, Kelly',
#  'Dialer, Doris',
#  'Diamant, Neil Jeffrey',
#  'Diamond, Jared',
#  'Diamond, Larry',
#  'Diamond, Larry Jay',
#  'Diamond, Matthew',
#  'Dib, Laiena T.',
#  'Dickert, Stephan',
#  'Diego, Vigil James',
#  'Dinstein, Yoram',
#  'Dirks, Nicholas B.',
#  'Dittmer, Lothar',
#  'Dittmer, Lowell',
#  'Dodds, Peter Sheridan',
#  'Dodge, Theodore Ayrault',
#  'Dolinajec, Gregory',
#  'Domhoff, G. William',
#  'Donner, Fred M.',
#  'Doorenspleet, R.',
#  'Doornbos, Martin R.',
#  'Doreian, Patrick',
#  'Douglas, William A.',
#  'Downer, Lorann',
#  'Dumont, Louis',
#  'Dunning, Thad',
#  'Durkheim, Emile',
#  'Durlauf, Steven',
#  'Duverger, Maurice',
#  'Díez, Jordi',
#  'Eade, John Christopher',
#  'Eatwell, Roger',
#  'Ebrey, Patricia Buckley',
#  'Edling, Christofer R.',
#  'Edwards, Brad',
#  'Egan, David',
#  'Egan, Melinda',
#  'Egle, William Henry',
#  'Egnal, Marc',
#  'Eisenstadt, Lemarchand',
#  'Eisenstadt, Shmuel Noah',
#  'El-Husseini, Rola',
#  'Ellickson, Robert C.',
#  'Ellis, Andrew',
#  'Elvin, Mark',
#  'Emmott, Bill',
#  'Engal, Pal',
#  'Engels, Friedrich',
#  'Engerman, Stanley L.',
#  'Englebert, Pierre',
#  'Englehart, Neil A.',
#  'Enyedi, Zsolt',
#  'Eom, Kihong',
#  'Eom, Kimin',
#  'Erickson, Bonnie H.',
#  'Erickson, Kristan\xa0Glasgow',
#  'Ertman, Thomas',
#  'Eun, Ki-Soo',
#  'Eunyoung, Soh',
#  'Evans, Peter',
#  'Evans-Pritchard, Edward Evan',
#  'Fa, John E.',
#  'Fabbri, Lorenzo',
#  'Fagan, Teresa Lavender',
#  'Fararo, Thomas J.',
#  'Farris, William Wayne',
#  'Faust, Katherine',
#  'Fedigan, Linda M.',
#  'Feldman, Noah',
#  'Feldman, Shel',
#  'Fennell, Mary L.',
#  'Ferguson, Brian',
#  'Ferguson, R. Brian',
#  'Ferguson, Russell J.',
#  'Fernandez, Roberto M.',
#  'Ferris, Gerald',
#  'Festinger, Leon',
#  'Feuerbach, Ludwig',
#  'Figueira, José E. C.',
#  'Findley, William',
#  'Finer, Samuel Edward',
#  'Firth, Raymond',
#  'Fischer, Claude S.',
#  'Fischer, David Hackett',
#  'Fischer, Wolfram',
#  'Fish, M. Steven',
#  'Flache, Andreas',
#  'Flanagan, Tom',
#  'Flexner, James Thomas',
#  'Fligstein, Neil',
#  'Flores, Alexandra',
#  'Flórez, Fernando Carrillo',
#  'Fogel, Robert William',
#  'Foltz, William J.',
#  'Forey, Alan',
#  'Formisano, Ronald P.',
#  'Forrest, Tom',
#  'Forsgren, Elisabet',
#  'Fortes, Meyer',
#  'Foschi, Martha',
#  'Foster, George M.',
#  'Foster, William Eaton',
#  'Fourquin, Guy',
#  'Franceschet, Susan',
#  'Frank, Robert',
#  'Frank, Robert H.',
#  'Freedman, Jim',
#  'Freeland, Robert F.',
#  'Freeman, Linton C.',
#  'Friedell, Morris F.',
#  'Friedkin, Noah E.',
#  'Friedrich, Karl Joachim',
#  'Friedrich, Paul',
#  'Fukui, Haruhiro',
#  'Fukuyama, Francis',
#  'Fukuyama, Professor of International Political Economy Francis',
#  'Fuller, John Frederick Charles',
#  'Fuller, Sylvia',
#  'Furet, François',
#  'Gallman, Robert E.',
#  'Gallup, John Luke',
#  'Galston, William Arthur',
#  'Gambetta, Diego',
#  'Ganev, Venelin J.',
#  'Ganshof, F. L.',
#  'Ganter, Bernhard',
#  'Garlan, Yvon',
#  'Garry, Wills',
#  'Gasser, E.B.',
#  'Gathmann, Christina',
#  'Gauja, Anika',
#  'Gauja, Dr Anika',
#  'Gazibo, Mamoudou',
#  'Geddes, Barbara',
#  'Gellner, Ernest',
#  'Gerschenkron, Alexander',
#  'Gerson, Kathleen',
#  'Gerstel, David U.',
#  'Gerth, H. H.',
#  'Gethin, Amory',
#  'Gherghina, Sergiu',
#  'Gibson, Rachel Kay',
#  'Gigerenzer, Gerd',
#  'Gill, Graeme',
#  'Gilley, Bruce',
#  'Gilman, Nils',
#  'Ginsborg, Paul',
#  'Ginsburg, Benson',
#  'Giovanni, Sartori',
#  'Glanzer, Murray',
#  'Glaser, Robert',
#  'Goffman, Erving',
#  'Goldstone, Jack A.',
#  'Goldsworthy, Adrian Keith',
#  'Gong, Qian',
#  'Goodale, Jane Carter',
#  'Goodall, Jane',
#  'Goodwyn, Lawrence',
#  'Goody, Jack',
#  'Goody, John Rankine',
#  'Gordon, Andrew',
#  'Gordon, Thomas P.',
#  'Gore, Lance',
#  'Gorski, Philip S.',
#  'Gottweis, Herbert',
#  'Gould, Roger V.',
#  'Gouldner, Alvin W.',
#  'Goyal, Sanjeev',
#  'Granovetter, Mark',
#  'Granovetter,, Mark',
#  'Gray, Kevin',
#  'Graziano, Luigi',
#  'Green, Christopher K.',
#  'Greenhalgh, Pal',
#  'Grofman, Bernard',
#  'Gross, Donald A.',
#  'Gross, Jonathan L.',
#  'Grossman, Jerrold W.',
#  'Grzelczyk, Virginie',
#  'Gu, Kang Myung',
#  'Guasti, Laura',
#  'Gunawardana, Ralh',
#  'Guo, Sujian',
#  'Guo, Xuezhi',
#  'Gupta, Akhil',
#  'Guriev, Sergei',
#  'Gustafson, Thane',
#  'Gwan, Park Jong',
#  'Ha, Nam-Gil',
#  'Ha, Se Hun',
#  'Haas, Jonathan',
#  'Haber, Stephen',
#  'Hacker, Jacob S.',
#  'Hage, Per',
#  'Hagedorn, John M.',
#  'Hagermann, Charles D.',
#  'Hahm, Chaibong',
#  'Hahn, Fank Horace',
#  'Haing-Ja, Kim',
#  'Hall, Anthony',
#  'Hall, John A.',
#  'Hamilton, Allan McLane',
#  'Hamilton, Charles V.',
#  'Hamlin, Paul Mahlon',
#  'Hammel, Eugene A.',
#  'Hammer, Muriel',
#  'Hammerstein, Peter',
#  'Hammond, Peter B.',
#  'Han, Ain',
#  'Han, JeongHun',
#  'Han, Jongwoo',
#  'Han, Miejeong',
#  'Han, Oul',
#  'Han, Seung Hui',
#  'Han, Sungjoo',
#  'Han, Yung Chul',
#  'Hanfmann, Eugenia',
#  'Hanks, Lucien M.',
#  'Hanson, Victor Davis',
#  'Harary, Frank',
#  'Haraway, Donna J.',
#  'Harding, Susan',
#  'Hareven, Tamara',
#  'Harrington, Ann M.',
#  'Harris, Kevan',
#  'Harrison, Lawrence E.',
#  'Harrison, Robert',
#  'Harrison, White',
#  'Harré, Rom',
#  'Hart, Charles William Merton',
#  'Hartmann, Rudolph H.',
#  'Harton, H. C.',
#  'Harvey, Ross',
#  'Haskard, Alec',
#  'Hassig, Ross',
#  'Hathaway, Jane',
#  'Hauser, Marc',
#  'Hausfater, Glenn',
#  'Hausmann, Ricardo',
#  'Haviland, William A.',
#  'Havrylyshyn, Oleh',
#  'Hawley, Willis D.',
#  'Hayano, David M.',
#  'Hayek, F. A.',
#  'Hayek, Friedrich August',
#  'Hazard, Samuel',
#  'Hechter, Michael',
#  'Hedrick, Charles',
#  'Hedström, Peter',
#  'Hegel, Georg Wilhelm Friedrich',
#  'Heider, Fritz',
#  'Helgesen, Geir',
#  'Heller, Thomas C.',
#  'Hellman, Joel',
#  'Hellmann, Olli',
#  'Helm, June',
#  'Henderson, Gregory',
#  'Henderson, Herbert James',
#  'Hendrickson, Robert A.',
#  'Hengeveld, Geerten M.',
#  'Henry, Jules',
#  'Heo, Uk',
#  'Herbert, Simon',
#  'Hermanns, Heike',
#  'Herschkorn, Stephen J.',
#  'Herz, Dietmar',
#  'Hewlett, Barry S.',
#  'Hibbing, John R.',
#  'Hicken, Allen',
#  'Hicks, Frederic',
#  'Hicks, John Donald',
#  'Hildebrand, Polly',
#  'Hill, Michael',
#  'Hillmann, Henning',
#  'Hinde, R. A.',
#  'Hintze, Otto',
#  'Hirschman, Albert',
#  'Hirschman, Albert O.',
#  'Hix, Simon',
#  'Ho, Lok-sang',
#  'Hoadley, John F.',
#  'Hobbes, Thomas',
#  'Hobsbawm, Eric J.',
#  'Hochul, Sonn',
#  'Hofstadter, Richard',
#  'Holborn, Hajo',
#  'Holland, Paul W.',
#  'Holzer, Boris',
#  'Holzhacker, Ronald Lindsey',
#  'Homans, George C.',
#  'Hong, Sounman',
#  'Hoogenboom, Ari Arthur',
#  'Hoogenboom, Olive',
#  'Horowitz, Ruth',
#  'Horowitz, Shale',
#  'House, Floyd N.',
#  'Houseman, Michael',
#  'Housley, Norman',
#  'Hoyle, Rick H.',
#  'Hsing, Associate Professor of Geography You-Tien',
#  'Hsing, You-tien',
#  'Hsu, Chien-leng',
#  'Hsu, Cho-Yun',
#  'Huang, Chên-hsia',
#  'Hucker, Charles O.',
#  'Huh, Hun',
#  'Hummon, Norman P',
#  'Hun, Huh',
#  'Hundt, David',
#  'Hunt, Tristram',
#  'Hunter, Janet',
#  'Hutchcroft, Paul David',
#  'Huxtable, Phillip',
#  'Hwang, Ah-Ran',
#  'Hwang, Sungwook',
#  'Hwang, Wonjae',
#  'Hyden, Goran',
#  'Hydén, Göran',
#  'Hyman, Harold M.',
#  'Hölldobler, Bert',
#  'Ike, Nobutaka',
#  'Ikegami, Eiko',
#  'Ikramov, M. A.',
#  'Ilchman, Warren Frederick',
#  'Im, Hyug Baeg',
#  'Im, Mi-Kyung',
#  'Inglehart, Ronald',
#  'Intan, Benyamin Fleming',
#  'Ip, Eric',
#  'Isbell, Lynne A.',
#  'Ishiyama, John',
#  'Iverson, Geoffrey J.',
#  'Ives, John W.',
#  'Iyer, Lakshmi',
#  'Jackson, Matthew O.',
#  'Jackson, Michael',
#  'Jackson, Robert',
#  'Jacobs, Jane',
#  'Jacobs, Joachim',
#  'Jacobstein, Helen L.',
#  'James, Alfred P.',
#  'Jamison, Kay Redfield',
#  'Jankowski, Martin Sanchez',
#  'Jannou, Christopher',
#  'Janowitz, Morris',
#  'Jansen, Marius B.',
#  'Janzen, Rod',
#  'Jd, Bygott',
#  'Jennings, Francis',
#  'Jensen, Erik Gilbert',
#  'Jensen, Merrill',
#  'Jeong, Ji Su',
#  'Jeong, Sangho',
#  'Jesse, Neal',
#  'Jhee, Byong-Kuen',
#  'Jia, Ruixue',
#  'Jiga-Boy, Gabriela M.',
#  'Jillson, Calvin C.',
#  'Jin, Youngjae',
#  'Joe, Dong-Hee',
#  'Joffe, Josef',
#  'Johnsen, Eugene C.',
#  'Johnson, Avery',
#  'Johnson, Chalmers',
#  'Johnson, Hubert C.',
#  'Johnson, Simon',
#  'Johnson, Terry',
#  'Johnson, Timothy',
#  'Jomo, Kwame Sundaram',
#  'Jonas, Kai',
#  'Jones, Geraint',
#  'Jones, J. R.',
#  'Jones, Nicola',
#  'Joyce, Appleby',
#  'Joyce, Mary',
#  'Jun, Hae-Won',
#  'Jung, Hoyong',
#  'Jung, Soo Hyun',
#  'Jung, Yonju',
#  'Jung, Young-Mi',
#  'Jung, Yui-Ryong',
#  'KAGAN, Robert A.',
#  'Kagan, Donald',
#  'Kagan, Robert A.',
#  'Kaminski, John P.',
#  'Kane, Joshua',
#  'Kang, David C.',
#  'Kang, Woo Chang',
#  'Kant, Immanuel',
#  'Kapferer, Bruce',
#  'Kaplan, Jay R.',
#  'Kaplan, Robert D.',
#  'Kaplan, Seth',
#  'Kapsalis, Ellen',
#  'Kasakoff, Alice',
#  'Katz, Elihu',
#  'Katz, Richard S.',
#  'Katz, Stanley Nider',
#  'Kaufman, Herbert',
#  'Kaufman, Robert R.',
#  'Kaumanns, Werner',
#  'Kaviraj, Sudipta',
#  'Kawai, Masao',
#  'Kawata, Junichi',
#  'Keegan, J.',
#  'Keegan, John',
#  'Keen, Maurice',
#  'Keesing, Roger M.',
#  'Keister, Lisa A.',
#  'Kelemen, R. Daniel',
#  'Kemp, Jeremy H.',
#  'Kemper, Theodore D.',
#  'Kennedy, John G.',
#  'Kennedy, Robert F.',
#  'Kent, Francis William',
#  'Kerkuliet, Benedict J.',
#  'Ketcham, Ralph',
#  'Kettering, Sharon',
#  'Key, Valdimer Orlando',
#  'Khan, Mushtaq H.',
#  'Kierman, Frank A.',
#  'Kihl, Young-Whan',
#  'Kil, Soong Hoom',
#  'Killworth, Peter D.',
#  'Kim, Beomsoo',
#  'Kim, Byoungsoo',
#  'Kim, Byung-Kook',
#  'Kim, C. I. Eugene',
#  'Kim, Chae-Han',
#  'Kim, Chang-jin',
#  'Kim, Cheonsoo',
#  'Kim, Chong Lim',
#  'Kim, Chun-Sik',
#  'Kim, Claire Jean',
#  'Kim, Dae Youn',
#  'Kim, Eun Mee',
#  'Kim, Haingja',
#  'Kim, Hee Min',
#  'Kim, Hugh Hoikwang',
#  'Kim, Hye-Sung',
#  'Kim, Hyo Jung',
#  'Kim, Hyunhee',
#  'Kim, Jae-on',
#  'Kim, Jaechun',
#  'Kim, Jin-Mook',
#  'Kim, Kyŏng-su',
#  'Kim, Meengeon',
#  'Kim, Minjeoung',
#  'Kim, Nam-Kook',
#  'Kim, Paul Youngwook',
#  'Kim, Pyŏng-guk',
#  'Kim, Samuel S.',
#  'Kim, Sei-Hill',
#  'Kim, Soyeon',
#  'Kim, Sun Hyoung',
#  'Kim, Sun-gi',
#  'Kim, Sung Eun',
#  'Kim, Sung-Tae',
#  'Kim, Sunhyuk',
#  'Kim, Sunmi',
#  'Kim, Sunwoong',
#  'Kim, Taewan',
#  'Kim, Wonik',
#  'Kim, Youngmi',
#  'King, Desmond',
#  'King, Wesley',
#  'Kipnis, Andrew B.',
#  'Kirby, William',
#  'Kiser, Edgar',
#  'Kitschelt, Herbert',
#  'Kleinberg, Jon M.',
#  'Klitgaard, Robert',
#  'Kluver, Randolph',
#  'Knack, Stephen F.',
#  'Knox, Kerry L.',
#  'Ko, Kyung Hun',
#  'Koechlin, Lucy',
#  'Koffka, Kurt',
#  'Kogut, Tehila',
#  'Koh, B. C.',
#  'Koh, Byung Chul',
#  'Kohli, Atul',
#  'Kollman, Ken',
#  'Kontopoulos, Kyriakos M.',
#  'Koo, Hagen',
#  'Kopelowitz, Ezra',
#  'Kopsieker, Fritz',
#  'Koskinen, Johan',
#  'Kpundeh, Sahr John',
#  'Krackhardt, David',
#  'Krebs, Dennis',
#  'Kroeber, A. L.',
#  'Kuhlmann, Sabine',
#  'Kuhonta, Erik Martinez',
#  'Kujala, Jordan',
#  'Kummer, Hans',
#  'Kutlay, Mustafa',
#  'Kwak, Seung-Jin',
#  'Kwon, Soo Hyun',
#  'Kües, Ursula',
#  'Lai, Gina',
#  'Laitin, David D.',
#  'Lam, Tao-chiu',
#  'Lambert, Charles',
#  'Lambiotte, Renaud',
#  'Land, Carl H.',
#  'Landau, H. G.',
#  'Landes, David S.',
#  'Landé, Carl H.',
#  'Lang, Kurt',
#  'Langenhove, Luk Van',
#  'Langmia, Kehbuma',
#  'Lanning, Kevin',
#  'Lansford, Jennifer E.',
#  'Larson, Erik',
#  'Larson, Magali Sarfatti',
#  'Latané, B.',
#  'Latour, Bruno',
#  'Laurent, Natacha',
#  'Lawrence, S. Stepelevich',
#  'Lawrence, Stone',
#  'Le Dressay, André',
#  'Leavitt, Harold J.',
#  'Lee, Chae-Jin',
#  'Lee, Chung Min',
#  'Lee, Don S.',
#  'Lee, Dong Ok',
#  'Lee, Eun-Ju',
#  'Lee, Hojun',
#  'Lee, Hong Yung',
#  'Lee, Hyangjin',
#  'Lee, Hye-Yon',
#  'Lee, Jeongjin',
#  'Lee, Jiho',
#  'Lee, Jinock',
#  'Lee, Junhan',
#  'Lee, Maurice',
#  'Lee, Min-Kyu',
#  'Lee, Nam Hee',
#  'Lee, Peter',
#  'Lee, Richard',
#  'Lee, SangChul',
#  'Lee, Sangmook',
#  'Lee, Seung-Chal',
#  'Lee, Seung-Ook',
#  'Lee, Soobum',
#  'Lee, Sung-Chull',
#  'Lee, Won-Tae',
#  'Lee, Yoonkyung',
#  'Lee, Young-Im',
#  'Leeson, Peter T.',
#  'Leheny, David',
#  'Leibiger, Stuart',
#  'Leifer, Eric M.',
#  'Leinhardt, Samuel',
#  'Lemarchand, René',
#  'Lenin, V. I.',
#  'Leonardi, Robert',
#  'Leontief, Wassily',
#  'Levi, Margaret',
#  'Levi-Strauss, Claude',
#  'Levine, Donald N.',
#  'Levine, Laura',
#  'Levitt, Steven D.',
#  'Levy, Brian',
#  'Lewis, Peter',
#  'Li, Cheng',
#  'Library, United States Office of Personnel Management',
#  'Lie, John',
#  'Lieberman, Robert C.',
#  'Lieberson, Stanley',
#  'Lim, Linda Y. C.',
#  'Lim, Yon Soo',
#  'Lindblom, Charles E.',
#  'Linn, John Blair',
#  'Linton, April',
#  'Linton, R.',
#  'Linz, Juan J.',
#  'Linz, Juan José',
#  'Lippitt, Ronald',
#  'Lipset, Seymour Martin',
#  'Lipsky, Michael',
#  'Liu, Guoli',
#  'Lió, Pietro',
#  'Llamazares, Iván',
#  'Lobell, Steven',
#  'Locke, Edwin A.',
#  'Lodge, Henry Cabot',
#  'Loewe, Michael',
#  'Loewenberg, Gerhard',
#  'Lokken, Roy N.',
#  'Lomask, Milton',
#  'Lorenz, Konrad Z.',
#  'Loria, Riley',
#  'Lorrain, François',
#  'Losson, Pierre',
#  'Louch, Hugh',
#  'Loy, James',
#  'Lu, Liancheng',
#  'Lubbers, Miranda J',
#  'Lubman, Stanley B.',
#  'Lubove, Roy',
#  'Luce, Edward',
#  'Luchsinger, Tobias',
#  'Luchterhandt, Galina',
#  'Lueck, Dean',
#  'Luhmann, Niklas',
#  'Lundberg, George',
#  'Lundgreen, Peter',
#  'Luongo, Katherine',
#  'Lusher, Dean',
#  'Luthin, Reinhard Henry',
#  'Lynn, John',
#  'Lyons, Martyn',
#  'López-Calva, Luis Felipe',
#  'MacArthur, Robert H.',
#  'MacCaffrey, Wallace T.',
#  'MacIntyre, Andrew',
#  'Macaulay, Neill',
#  'Macdonald, Donald Stone',
#  'Macguire, William James',
#  'Mackay, Charles',
#  'Mackesy, Piers',
#  'Macon, Perry',
#  'Macy, Michael W.',
#  'Maenchen-Helfen, J. Otto',
#  'Maggs, Peter',
#  'Maier, Charles',
#  'Main, Jackson T.',
#  'Maine, Henry Sumner',
#  'Mainwaring, Scott',
#  'Mair, Lucy P.',
#  'Major, J. Russell',
#  'Malinowski, Bronislaw',
#  'Mallaby, Sebastian',
#  'Malloy, James',
#  'Mamdani, Mahmood',
#  'Manent, Pierre',
#  'Mangan, James A.',
#  'Mangua, Charles',
#  ...]

# %% [markdown]
# # Publication Titles of Journal Articles - Clean & Disambiguate

# %%
dat.ItemType.unique()
# Out:
# array(['journalArticle', 'book', 'webpage', 'bookSection', 'document',
#        'report', 'conferencePaper', 'thesis'], dtype=object)

# %%
publist1 = dat[(dat.PublicationTitle.isnull() == False) & (dat.ItemType == "journalArticle")].PublicationTitle.str.strip()

# %%
# remove 'The ' from publication title
publist1 = [item.replace("The ","") for item in publist1]
publist1
# Out:
# ['American Journal of Sociology',
#  'formation of national states in Western Europe',
#  'Challenging Authority: Historical Study of Contentious Politics',
#  'Sociological Forum',
#  'Pennsylvania History: A Journal of Mid-Atlantic Studies',
#  'Theory and Society',
#  'Theory and Society',
#  'Minutes of the Provincial Council',
#  'formation of national states in western Europe',
#  'Western Pennsylvania History: 1918-2018',
#  'Statemaking and social movements: essays in history and theory',
#  'Last Emperor of China',
#  'Whiskey Rebellion, Past and Present Perspectives',
#  'formation of national states in Western Europe',
#  'Cambridge: Cambridge Univ. Press',
#  'Agricultural History',
#  'Annual Review of Sociology',
#  'CBR a. R. Radner. Amsterdam, NorthHolland',
#  'Ethnology',
#  'Chambers38Political Parties in a New Nation: American Experience',
#  'Korea Observer',
#  'Friends, Followers and Factions',
#  'Seoul: Baeksanseodang',
#  'Comparative Politics',
#  'Midwest Journal of Political Science',
#  'Journal of Modern African Studies',
#  'Electoral Studies',
#  'challenges of intra-party democracy',
#  'Friends, followers and factions: a reader in political clientelism',
#  'challenges of intra-party democracy',
#  'challenges of intra-party democracy',
#  'Dominance relations: An ethological view of human conflict and social interaction',
#  'American Sociological Review',
#  'History Today',
#  'Virginia Magazine of History and Biography',
#  'quoted phrase appears on',
#  'New York: Henry Holt. CBO9780511509742',
#  'Child development',
#  'Medieval Warfare: A History',
#  'American Journal of Sociology',
#  'Journal of Comparative and Physiological Psychology',
#  'Journal of the American Research Center in Egypt',
#  'Dominance relations: An ethological view of human conflict and social interaction',
#  'Southwestern Journal of Anthropology',
#  'Behaviour',
#  'American Journal of Sociology',
#  'American Journal of Sociology',
#  'American Journal of Sociology',
#  'American Scientist',
#  'Florentine Tuscany',
#  'Animal Behaviour',
#  'Journal of Comparative and Physiological Psychology',
#  'Social Science Research',
#  'Tulane Studies in Zoology',
#  'Albion',
#  'History: Reviews of New Books',
#  'Cahiers de Civilisation Médiévale',
#  'Social networks',
#  'Animal Behaviour',
#  'International Labor and Working-Class History',
#  'American Anthropologist',
#  'Journal of Comparative and Physiological Psychology',
#  'Animal Behaviour',
#  'Trans. Richard Nice. Stanford: Stanford University Press',
#  'American Journal of Sociology',
#  'Poetics',
#  'Social Forces',
#  'Biometrika',
#  'Social Networks',
#  'Social Networks',
#  'Journal of Mathematical Psychology',
#  'Physiological Zoology',
#  'Social Networks',
#  'Man',
#  'Journal of Roman Studies',
#  'great apes',
#  'Behaviour',
#  'Molecular Ecology',
#  'Sociological Theory',
#  'Science Studies',
#  'Sociometry',
#  'Introduction to mathematical sociology.',
#  'Hunters and Gatherers Today',
#  'Annales. Histoire, Sciences Sociales',
#  'American Political Science Review',
#  'Social Networks',
#  'Animal Behaviour',
#  'Animal Behaviour',
#  'Science',
#  'American Sociological Review',
#  'Behavioral Science',
#  'William and Mary Quarterly',
#  'History and Theory',
#  'Isis',
#  'Journal of Asian Studies',
#  'New York History',
#  'Behaviour',
#  'Behaviour',
#  'Journal of Mathematical Sociology',
#  'Human Relations',
#  'Animal Behaviour',
#  'Science',
#  'Etnosfera',
#  'Comparative Studies in Society and History',
#  'American Historical Review',
#  'Social Networks',
#  'Social Networks',
#  'Sex Roles',
#  'Canadian Journal of Sociology / Cahiers canadiens de sociologie',
#  'Political Science Quarterly',
#  'Social Networks',
#  'Ethnology',
#  'American Journal of Orthopsychiatry',
#  'VRÜ Verfassung und Recht in Übersee',
#  'Machiavellian Intelligence : Social Expertise and the Evolution of Intellect in Monkeys, Apes and Man',
#  'Self-organization of complex structures: From individual to collective dynamics',
#  'Simians, cyborgs and women: reinvention of nature',
#  "Revue belge de philologie et d'histoire",
#  'Catalyst',
#  'History: Reviews of New Books',
#  'Behavioral Science',
#  'American Sociological Review',
#  'Journal of Economic Theory',
#  'American Journal of Sociology',
#  'European Journal of Political Research',
#  'War in the Tribal Zone',
#  'Friends, Followers, and Factions: A Reader in Political Clientelism',
#  'London: Phoenix Giants',
#  'Psychological Bulletin',
#  'Man',
#  'American Journal of Sociology',
#  'American Sociological Review',
#  'Review of Religious Research',
#  'Physiological Zoology',
#  'Greeks, translated by C. Lambert and TL Fagan',
#  'Grierson (London, 1964)',
#  'Local-level politics: Social and cultural perspectives. Chicago: Aldine Pub. Co',
#  'American Political Science Review',
#  'American Anthropologist',
#  'American Anthropologist',
#  'Evolution of American Electoral Systems',
#  'SW Schmidt et alii',
#  'We, the Tikopia: A Sociological Study of Kinship in Primitive Polynesia',
#  'New York and Cambridge: Cambridge University Press',
#  'War in the tribal zone: Expanding states and indigenous warfare',
#  'Physica A: Statistical Mechanics and its Applications',
#  'Primate Societies',
#  'Social Networks',
#  'Social Forces',
#  'American Sociological Review',
#  'American Anthropologist',
#  'Primates',
#  'social anthropology of Latin America: Essays in honor of Ralph Leon Beals. Los Angeles: Latin American Center, University of California',
#  'Strategies and structures in Thai society',
#  'Medieval Warfare: A History',
#  'SPECTATOR-LONDON-WEEKLY-',
#  'Authoritarianism and corporatism in Latin America',
#  'Glencoe, Illinois: Free Press. KatzPersonal Influence: Part Played by People in the Flow of Mass Communication',
#  'Folia Primatologica',
#  'Conflict Resolution',
#  'Nova Religio',
#  'Social Networks',
#  'Social Networks',
#  'American Anthropologist',
#  'Unconscious in Culture, ed. I. Rossi',
#  'Patronage in ancient society',
#  'New York: Vintage',
#  'Journal of Economic Theory',
#  'Economics in Nature-Social Dilemmas, Mate Choice and Biological Markets',
#  'Social Networks',
#  'History: Reviews of New Books',
#  'Behaviour',
#  'Transformations of kinship',
#  'Journal of Quantitative Anthropology',
#  'Medieval Warfare: a history',
#  'Comparative Group Studies',
#  'Psychiatry',
#  'American Anthropologist',
#  'American Ethnologist',
#  'Perspectives of human evolution',
#  'American Political Science Review',
#  'Hunters and gatherers today',
#  'American Antiquity',
#  'American Ethnologist',
#  'American Journal of Sociology',
#  'Social Forces',
#  'Sociological Forum',
#  'Journal of Marriage and Family',
#  'American Sociological Review',
#  'Journal of Mathematical Sociology',
#  '한국지방자치학회보',
#  'Korea and World Politics',
#  '한국정치학회보',
#  'Journal of Local Government Studis',
#  '한국정치학회보',
#  'Korea Local Administration Review',
#  '한국지방자치연구',
#  '한국지방정부학회 학술대회자료집',
#  '한국정당학회보',
#  'Korean Journal of Local Government & Administration Studies',
#  '한국지방정부학회 학술대회자료집',
#  '지방정부연구',
#  'Korean Party Studies Review',
#  'Korean Journal of Public Administration',
#  '세계헌법연구',
#  '한국정치학회보',
#  '한국정치학회보',
#  'Korea and World Politics',
#  '정치정보연구',
#  'Korean Journal of Policy Analysis and Evaluation',
#  '한국정치학회보',
#  '한국정책학회 추계학술발표논문집',
#  'Korea and World Politics',
#  'Korean Journal of Public Administration',
#  '사회과학연구',
#  'Peace Studies',
#  '정치정보연구',
#  '21st Century Political Science Review',
#  'Public Policy Review',
#  '의정논총',
#  '한국심리학회지: 문화 및 사회문제',
#  '한국정치연구',
#  '한국정당학회보',
#  '정치정보연구',
#  '정치정보연구',
#  '한국정치연구',
#  '한국정당학회보',
#  '한국정당학회보',
#  '한국정당학회보',
#  '세계헌법연구',
#  '한국정치학회보',
#  '세계헌법연구',
#  '21st Century Political Science Review',
#  '21세기정치학회보',
#  'Acta Sociologica',
#  'Behaviour',
#  '지방정부연구',
#  '21st Century Political Science Review',
#  '대한정치학회보',
#  'study of Election',
#  '의정연구',
#  '사회과학 담론과 정책',
#  'Journal of the Korea Contents Association',
#  'Journal of the Korea Contents Association',
#  '의정연구',
#  '한국정당학회보',
#  '한국지방자치연구',
#  'Korean Journal of Local Government Studies',
#  '한국정당학회보',
#  '의정연구',
#  'Korean Political Science Review',
#  'Korean Lawyers Association Journal',
#  '한국정치학회보',
#  'OUGHTOPIA',
#  '아태연구',
#  '한국정당학회보',
#  '아시아여성연구',
#  '경제와사회',
#  'Party Politics',
#  'American Political Science Review',
#  'Trends in Ecology & Evolution',
#  'Africa',
#  'Primates',
#  'Annual Review of Sociology',
#  'Journal of Voluntary Action Research',
#  'Journal of the History of the Behavioral Sciences',
#  'Philosophy of the Social Sciences',
#  'American Journal of Sociology',
#  'International Journal',
#  'Primate Societies',
#  'American Journal of International Law',
#  'Social Forces',
#  'Sociological Methods & Research',
#  'American Journal of Sociology',
#  'Politics & Society',
#  'China Quarterly',
#  'Theory and Society',
#  'Bulletin of the Atomic Scientists',
#  'Oceania',
#  'ANNALS of the American Academy of Political and Social Science',
#  'American Journal of Sociology',
#  'Southwestern Journal of Anthropology',
#  'American Journal of Primatology',
#  'Social Networks',
#  'Party Politics',
#  'ANNALS of the American Academy of Political and Social Science',
#  'Social Networks',
#  'Zoologica',
#  'American Journal of Sociology',
#  'Comparative Studies in Society and History',
#  'Renaissance Quarterly',
#  'Human Relations',
#  'Social Forces',
#  'Journal of Mathematical Sociology',
#  'Social Networks',
#  'Social Networks',
#  'Osteuropa',
#  'French Historical Studies',
#  'Canadian Historical Review',
#  'William and Mary Quarterly',
#  "Cahiers d'Études Africaines",
#  'International Journal of African Historical Studies',
#  'American Historical Review',
#  'Journal of Politics',
#  'Review of Radical Political Economics',
#  'Review of Radical Political Economics',
#  'Africa',
#  'Social Networks',
#  'Philosophy of the Social Sciences',
#  'Journal of Mathematical Sociology',
#  'Theory and Society',
#  'Social Psychology Quarterly',
#  'Social Networks',
#  'Max Knight (Berkeley: University of California Press, 1973)',
#  'Bentley (reprint ed., New York: Harmony Books 1980)',
#  'Urbana: University of Illinois Press',
#  'Knodt. Writing science',
#  'Economic Systems',
#  'American Sociological Review',
#  'American Political Science Review',
#  'Theory, Culture & Society',
#  'Annual Review of Sociology',
#  'bulletin of mathematical biophysics',
#  'American Political Science Review',
#  'Journal of Economic History',
#  'Journal for General Philosophy of Science / Zeitschrift für Allgemeine Wissenschaftstheorie',
#  'Journal of Abnormal and Social Psychology',
#  'ANNALS of the American Academy of Political and Social Science',
#  'Anthropology today',
#  'Hunters and',
#  'Friends, Followers and Factions: A Reader in political clientelism',
#  'Friends, followers and factions: a reader in political clientelism',
#  'American Sociological Review',
#  'American Sociological Review',
#  'American Journal of Sociology',
#  'Social Forces',
#  'American Sociological Review',
#  'Nature',
#  'International Journal of Primatology',
#  'Theory and Society',
#  'Public Culture',
#  'Animal Behaviour',
#  'baboon in medical research',
#  'American Historical Review',
#  'Social Networks',
#  'Philosophy and Scientific Method',
#  'Politics & Society',
#  'Strategies and structures in Thai society. Amsterdam: Anthropologisch-Sociologisch Centrum',
#  'Dominance relations: An ethological view of human conflict and social interaction',
#  'American Sociological Review',
#  'Man',
#  'American Sociological Review',
#  'Primates',
#  'Behaviour',
#  'Primate Societies',
#  'Primate societies',
#  'Journal of Hellenic Studies',
#  'South African Journal of Science',
#  'Social Science Quarterly',
#  'Sozialer Sinn',
#  'Proceedings of the American Philosophical Society',
#  'Conflict (Kurt H. Wolff, Trans.). New York, NY: Free Press of Glencoe',
#  'Research on Democracy and Society',
#  'challenge of social control',
#  'Theoretical perspectives on urban politics',
#  'Calcutta Univeristy',
#  'American Journal of Sociology',
#  'Games and Economic Behavior',
#  'Animal Behaviour',
#  'Sociological Theory',
#  'Social Communication Among Primates',
#  'Folia Primatologica',
#  'American Journal of Physical Anthropology',
#  'Comparative Studies in Society and History',
#  'Pacific Viewpoint',
#  'Animal Behaviour',
#  'Journal of Youth and Adolescence',
#  'Zeitschrift für Psychologie und Physiologie der Sinnesorgane. Abt. 1. Zeitschrift für Psychologie',
#  'Canadian Journal of Political Science/Revue canadienne de science politique',
#  'American Political Science Review',
#  'American Journal of Sociology',
#  'American Sociological Review',
#  'Nature',
#  'Patronage in ancient society',
#  "Unaonsaious in Culture, New YOl'k: EP Dutton",
#  'Ecology and Behavior of Food-Enhanced Primate Groups. JE Fa & CH Southwick (eds.). New York: Alan R. Liss, Inc',
#  'Southwestern Journal of Anthropology',
#  'sahoekwakyoyuk(social studies education)',
#  '의정연구',
#  '지방정부연구',
#  '지방정부연구',
#  'Korean Political Science Review',
#  '의정논총',
#  '한국지방자치연구',
#  '의정논총',
#  'American Sociological Review',
#  'American Mathematical Monthly',
#  'Comparative Studies in Society and History',
#  'English Historical Review',
#  'Pennsylvania Magazine of History and Biography',
#  'Science',
#  'English Historical Review',
#  'American Sociological Review',
#  'Sociological Methodology',
#  'American Journal of Sociology',
#  'Journal of Sex Research',
#  'Journal of Political Economy',
#  'Journal of Economic Literature',
#  'New York: Henry Holt',
#  'War in the tribal zone: expanding states and indigenous warfare',
#  'Anthropology of War',
#  'Harvard Univ',
#  'Dominance relations',
#  "and the same author's Toward an American Army",
#  'From Max Weber: Essays in Sociology',
#  'Patronage in ancient society',
#  'New York History',
#  'Personal Research Collection',
#  'Theory and Society',
#  'Zeitschrift für Tierpsychologie',
#  'Primate Societies',
#  'American Journal of Physical Anthropology',
#  'Transformations of kinship',
#  'Austin: University of Texas',
#  'Dominance relations: An ethological view of human conflict and social interaction',
#  'Child Development',
#  'American Journal of Physical Anthropology',
#  'Behaviour',
#  'Nature',
#  'Developments in Animal and Veterinary Sciences (Netherlands). no. 4.',
#  'Journal of Asian Studies',
#  'Canadian Journal of History',
#  'study of Election',
#  '사회과학연구',
#  'Korea and World Politics',
#  '의정논총',
#  '한국정책학회 추계학술발표논문집',
#  '한국지방정부학회 학술대회자료집',
#  '지방정부연구',
#  'Journal of Korean Women＇s Studies',
#  '한국정치연구',
#  '한국동북아논총',
#  'Comparative Democratic Studies',
#  '의정연구',
#  '이화젠더법학',
#  'study of Election',
#  'JOURNAL OF FUTURE POLITICS',
#  'Journal of Korean Social Trend and Perspective',
#  'Ewha Journal of Gender and Law',
#  '이화젠더법학',
#  '대한정치학회보',
#  '대한정치학회보',
#  '대한정치학회보',
#  '한국정당학회보',
#  '21st Century Political Science Review',
#  'Asian Perspective',
#  'Asian Survey',
#  'Korea Observer',
#  'Democratization',
#  'Taiwan Journal of Democracy',
#  'Pacific Affairs',
#  'Comparative Political Studies',
#  'Korea Observer',
#  'Pacific Focus',
#  'Party Politics',
#  'Feasibility of the Democratic Developmental State in the South',
#  'Asian Journal of Political Science',
#  'International Political Science Review',
#  'Journal of East Asian Studies',
#  'ASIEN',
#  'Asian New Democracies: Philippines, South Korea and Taiwan Compared',
#  'Korea Journal',
#  'Electoral studies',
#  'Political Oppositions in Industrialising Asia',
#  'Party Politics',
#  'Korea Review of International Studies',
#  'Foreign Affairs',
#  'New Media & Society',
#  'East Asia',
#  'Electoral Studies',
#  'Emerging Markets Finance and Trade',
#  'Party Politics',
#  'Asian Survey',
#  'Journal of Politics',
#  'Asian Survey',
#  'Development and Society',
#  'Party Politics',
#  'Pacific Affairs',
#  "Asian Journal of Women's Studies",
#  'Korea Journal',
#  'Applied Economics Letters',
#  'E. Asia L. Rev.',
#  'Journal of Asian Studies',
#  'Journal of Democracy',
#  'Asian Survey',
#  'Quality & Quantity',
#  'Review of International Organizations',
#  '한국로고스경영학회 학술발표대회논문집',
#  '한국정치학회보',
#  'Government information quarterly',
#  'Journal of Communication',
#  'Pacific Focus',
#  'Arms Control Today',
#  'Korea Journal',
#  'Quality & Quantity',
#  'Journal of public relations research',
#  'Korean journal of communication and information',
#  'Government Information Quarterly',
#  'International Journal of Costume and Fashion',
#  'Journalism',
#  'Asia pacific business review',
#  'Asian Survey',
#  'Asian Survey',
#  'Mass Communication & Society',
#  'Korean Studies',
#  'Asian Survey',
#  'Communication Research',
#  'Korea Observer',
#  'Political Quarterly',
#  'Proceedings of the National Academy of Sciences',
#  'Social Science Journal',
#  'Computers in Human Behavior',
#  'Available at SSRN 4040810',
#  'Taiwan Journal of Democracy',
#  'International Journal of Humanities and Social Sciences',
#  'Asian Politics & Policy',
#  'Policy & Politics',
#  "Nat'l Mun. Rev.",
#  '한국행정논집',
#  'Korea Observer',
#  'JeDEM-eJournal of eDemocracy and Open Government',
#  'Government Information Quarterly',
#  'Journal of the Korea Contents Association',
#  '한국수사학회 학술대회',
#  'Globalization and democratization in Asia. construction of identity. London: Routledge',
#  'Journal of Democracy',
#  'International relations of the Asia-Pacific',
#  'Third World Quarterly',
#  'Democratization',
#  'Asian Survey',
#  'Berkman Center Research Publication',
#  'Democratization',
#  'Polish Pol. Sci. YB',
#  'Political Studies',
#  'Korea observer',
#  'Journal of Asian Studies',
#  'Taiwan Journal of Democracy',
#  'International Journal of Cultural Policy',
#  'Journal of Northeast Asian Studies',
#  'good society',
#  'Korea Journal',
#  'Journal of Asian and African Studies',
#  'To aid in achieving its stated purposes and objectives this GCOE program launched a journal which publishes its academic research results in academic year 2008. Adopting the first letters from the GCOE’s program title “Gender Equality and Multicultural Conviviality”, this periodical was named “GEMC journal”. Since academic year 2009, we have published two GEMC journals, English and Japanese volumes every',
#  'Journal of Asian and African Studies',
#  'Portal: Journal of Multidisciplinary International Studies',
#  'Korean Journal',
#  'Journal of East Asian Studies',
#  'Japanese Journal of Political Science',
#  'Studies in Comparative Communism',
#  'Journal of Contemporary Asia',
#  'Communist and Post-Communist Studies',
#  'Asian Survey',
#  'Party Politics',
#  'Party politics',
#  '한국정치연구 (Journal of Korean Politics)',
#  'International Political Science Review',
#  'Asian Survey',
#  'Review of Korean Studies',
#  'Journal of East Asian Affairs',
#  'Political Geography',
#  'Research and Dialogue on Programmatic Parties and Party Systems: Case Study Reports',
#  'Development and Society',
#  'Electoral Studies',
#  'International Journal of Korean Studies',
#  'Japanese Journal of Political Science',
#  'Comparative Political Studies',
#  'Electoral Studies',
#  'Government information quarterly',
#  'Government and Opposition',
#  '한국언론학보',
#  'Journal of the Korean Society for Library and Information Science',
#  'Korea Observer',
#  'Legislative Studies Quarterly',
#  'Japanese Journal of Political Science',
#  'Korean Journal of Policy Studies',
#  'Asian Perspective',
#  'Journal of Legislative Studies',
#  'Midwest Journal of Political Science',
#  'Asian Survey',
#  'Asian Perspective',
#  'Electoral Studies',
#  'Asian survey',
#  'Party politics',
#  'Asian Survey',
#  'Pacific Affairs',
#  'New Political Science',
#  'Korean studies',
#  'Journal of Urban Technology',
#  'Science, technology, & human values',
#  'Korean Strategic Review, Carnegie Endowment for International Peace. https://carnegieendowment. org/2018/11/16/president-moon-jae-in-and-politics-of-inter-korean-d-tente-pub-77730)(17 July 2020, date last accessed)',
#  'Asian Perspective',
#  'Social Science Computer Review',
#  'Journal of Asian and African Studies',
#  'Portal: Journal of Multidisciplinary International Studies',
#  'To aid in achieving its stated purposes and objectives this GCOE program launched a journal which publishes its academic research results in academic year 2008. Adopting the first letters from the GCOE’s program title “Gender Equality and Multicultural Conviviality”, this periodical was named “GEMC journal”. Since academic year 2009, we have published two GEMC journals, English and Japanese volumes every',
#  'Journal of Asian and African Studies',
#  'International Journal of the History of Sport',
#  'Korea Journal',
#  'Portal: Journal of Multidisciplinary International Studies',
#  'Party Politics',
#  'International Interactions',
#  'Japanese Journal of Electoral Studies',
#  'Korean Journal',
#  'Japanese Journal of Political Science',
#  'Review of Political Economy',
#  'Asian Survey',
#  '한국정치연구 (Journal of Korean Politics)',
#  'International Political Science Review',
#  'Party Politics',
#  'Political Geography',
#  'Review of Korean Studies',
#  'Party politics']

# %%
# remove duplicate names and sort alphabetically
length_with_duplicates = len(publist1)
print("With Duplicates:",length_with_duplicates)

publist2 = list(set(publist1))
publist2.sort()
length_without_duplicates = len(publist2)

print("Without Duplicates:",length_without_duplicates)

print("Duplicates:",length_with_duplicates-length_without_duplicates)
# Out:
# With Duplicates: 622
# Without Duplicates: 354
# Duplicates: 268

# %%
publist2
# Out:
# ['21st Century Political Science Review',
#  '21세기정치학회보',
#  'ANNALS of the American Academy of Political and Social Science',
#  'ASIEN',
#  'Acta Sociologica',
#  'Africa',
#  'Agricultural History',
#  'Albion',
#  'American Anthropologist',
#  'American Antiquity',
#  'American Ethnologist',
#  'American Historical Review',
#  'American Journal of International Law',
#  'American Journal of Orthopsychiatry',
#  'American Journal of Physical Anthropology',
#  'American Journal of Primatology',
#  'American Journal of Sociology',
#  'American Mathematical Monthly',
#  'American Political Science Review',
#  'American Scientist',
#  'American Sociological Review',
#  'Animal Behaviour',
#  'Annales. Histoire, Sciences Sociales',
#  'Annual Review of Sociology',
#  'Anthropology of War',
#  'Anthropology today',
#  'Applied Economics Letters',
#  'Arms Control Today',
#  'Asia pacific business review',
#  'Asian Journal of Political Science',
#  "Asian Journal of Women's Studies",
#  'Asian New Democracies: Philippines, South Korea and Taiwan Compared',
#  'Asian Perspective',
#  'Asian Politics & Policy',
#  'Asian Survey',
#  'Asian survey',
#  'Austin: University of Texas',
#  'Authoritarianism and corporatism in Latin America',
#  'Available at SSRN 4040810',
#  'Behavioral Science',
#  'Behaviour',
#  'Bentley (reprint ed., New York: Harmony Books 1980)',
#  'Berkman Center Research Publication',
#  'Biometrika',
#  'Bulletin of the Atomic Scientists',
#  'CBR a. R. Radner. Amsterdam, NorthHolland',
#  "Cahiers d'Études Africaines",
#  'Cahiers de Civilisation Médiévale',
#  'Calcutta Univeristy',
#  'Cambridge: Cambridge Univ. Press',
#  'Canadian Historical Review',
#  'Canadian Journal of History',
#  'Canadian Journal of Political Science/Revue canadienne de science politique',
#  'Canadian Journal of Sociology / Cahiers canadiens de sociologie',
#  'Catalyst',
#  'Challenging Authority: Historical Study of Contentious Politics',
#  'Chambers38Political Parties in a New Nation: American Experience',
#  'Child Development',
#  'Child development',
#  'China Quarterly',
#  'Communication Research',
#  'Communist and Post-Communist Studies',
#  'Comparative Democratic Studies',
#  'Comparative Group Studies',
#  'Comparative Political Studies',
#  'Comparative Politics',
#  'Comparative Studies in Society and History',
#  'Computers in Human Behavior',
#  'Conflict (Kurt H. Wolff, Trans.). New York, NY: Free Press of Glencoe',
#  'Conflict Resolution',
#  'Democratization',
#  'Development and Society',
#  'Developments in Animal and Veterinary Sciences (Netherlands). no. 4.',
#  'Dominance relations',
#  'Dominance relations: An ethological view of human conflict and social interaction',
#  'E. Asia L. Rev.',
#  'East Asia',
#  'Ecology and Behavior of Food-Enhanced Primate Groups. JE Fa & CH Southwick (eds.). New York: Alan R. Liss, Inc',
#  'Economic Systems',
#  'Economics in Nature-Social Dilemmas, Mate Choice and Biological Markets',
#  'Electoral Studies',
#  'Electoral studies',
#  'Emerging Markets Finance and Trade',
#  'English Historical Review',
#  'Ethnology',
#  'Etnosfera',
#  'European Journal of Political Research',
#  'Evolution of American Electoral Systems',
#  'Ewha Journal of Gender and Law',
#  'Feasibility of the Democratic Developmental State in the South',
#  'Florentine Tuscany',
#  'Folia Primatologica',
#  'Foreign Affairs',
#  'French Historical Studies',
#  'Friends, Followers and Factions',
#  'Friends, Followers and Factions: A Reader in political clientelism',
#  'Friends, Followers, and Factions: A Reader in Political Clientelism',
#  'Friends, followers and factions: a reader in political clientelism',
#  'From Max Weber: Essays in Sociology',
#  'Games and Economic Behavior',
#  'Glencoe, Illinois: Free Press. KatzPersonal Influence: Part Played by People in the Flow of Mass Communication',
#  'Globalization and democratization in Asia. construction of identity. London: Routledge',
#  'Government Information Quarterly',
#  'Government and Opposition',
#  'Government information quarterly',
#  'Greeks, translated by C. Lambert and TL Fagan',
#  'Grierson (London, 1964)',
#  'Harvard Univ',
#  'History Today',
#  'History and Theory',
#  'History: Reviews of New Books',
#  'Human Relations',
#  'Hunters and',
#  'Hunters and Gatherers Today',
#  'Hunters and gatherers today',
#  'International Interactions',
#  'International Journal',
#  'International Journal of African Historical Studies',
#  'International Journal of Costume and Fashion',
#  'International Journal of Cultural Policy',
#  'International Journal of Humanities and Social Sciences',
#  'International Journal of Korean Studies',
#  'International Journal of Primatology',
#  'International Journal of the History of Sport',
#  'International Labor and Working-Class History',
#  'International Political Science Review',
#  'International relations of the Asia-Pacific',
#  'Introduction to mathematical sociology.',
#  'Isis',
#  'JOURNAL OF FUTURE POLITICS',
#  'Japanese Journal of Electoral Studies',
#  'Japanese Journal of Political Science',
#  'JeDEM-eJournal of eDemocracy and Open Government',
#  'Journal for General Philosophy of Science / Zeitschrift für Allgemeine Wissenschaftstheorie',
#  'Journal of Abnormal and Social Psychology',
#  'Journal of Asian Studies',
#  'Journal of Asian and African Studies',
#  'Journal of Communication',
#  'Journal of Comparative and Physiological Psychology',
#  'Journal of Contemporary Asia',
#  'Journal of Democracy',
#  'Journal of East Asian Affairs',
#  'Journal of East Asian Studies',
#  'Journal of Economic History',
#  'Journal of Economic Literature',
#  'Journal of Economic Theory',
#  'Journal of Hellenic Studies',
#  'Journal of Korean Social Trend and Perspective',
#  'Journal of Korean Women＇s Studies',
#  'Journal of Legislative Studies',
#  'Journal of Local Government Studis',
#  'Journal of Marriage and Family',
#  'Journal of Mathematical Psychology',
#  'Journal of Mathematical Sociology',
#  'Journal of Modern African Studies',
#  'Journal of Northeast Asian Studies',
#  'Journal of Political Economy',
#  'Journal of Politics',
#  'Journal of Quantitative Anthropology',
#  'Journal of Roman Studies',
#  'Journal of Sex Research',
#  'Journal of Urban Technology',
#  'Journal of Voluntary Action Research',
#  'Journal of Youth and Adolescence',
#  'Journal of public relations research',
#  'Journal of the American Research Center in Egypt',
#  'Journal of the History of the Behavioral Sciences',
#  'Journal of the Korea Contents Association',
#  'Journal of the Korean Society for Library and Information Science',
#  'Journalism',
#  'Knodt. Writing science',
#  'Korea Journal',
#  'Korea Local Administration Review',
#  'Korea Observer',
#  'Korea Review of International Studies',
#  'Korea and World Politics',
#  'Korea observer',
#  'Korean Journal',
#  'Korean Journal of Local Government & Administration Studies',
#  'Korean Journal of Local Government Studies',
#  'Korean Journal of Policy Analysis and Evaluation',
#  'Korean Journal of Policy Studies',
#  'Korean Journal of Public Administration',
#  'Korean Lawyers Association Journal',
#  'Korean Party Studies Review',
#  'Korean Political Science Review',
#  'Korean Strategic Review, Carnegie Endowment for International Peace. https://carnegieendowment. org/2018/11/16/president-moon-jae-in-and-politics-of-inter-korean-d-tente-pub-77730)(17 July 2020, date last accessed)',
#  'Korean Studies',
#  'Korean journal of communication and information',
#  'Korean studies',
#  'Last Emperor of China',
#  'Legislative Studies Quarterly',
#  'Local-level politics: Social and cultural perspectives. Chicago: Aldine Pub. Co',
#  'London: Phoenix Giants',
#  'Machiavellian Intelligence : Social Expertise and the Evolution of Intellect in Monkeys, Apes and Man',
#  'Man',
#  'Mass Communication & Society',
#  'Max Knight (Berkeley: University of California Press, 1973)',
#  'Medieval Warfare: A History',
#  'Medieval Warfare: a history',
#  'Midwest Journal of Political Science',
#  'Minutes of the Provincial Council',
#  'Molecular Ecology',
#  "Nat'l Mun. Rev.",
#  'Nature',
#  'New Media & Society',
#  'New Political Science',
#  'New York History',
#  'New York and Cambridge: Cambridge University Press',
#  'New York: Henry Holt',
#  'New York: Henry Holt. CBO9780511509742',
#  'New York: Vintage',
#  'Nova Religio',
#  'OUGHTOPIA',
#  'Oceania',
#  'Osteuropa',
#  'Pacific Affairs',
#  'Pacific Focus',
#  'Pacific Viewpoint',
#  'Party Politics',
#  'Party politics',
#  'Patronage in ancient society',
#  'Peace Studies',
#  'Pennsylvania History: A Journal of Mid-Atlantic Studies',
#  'Pennsylvania Magazine of History and Biography',
#  'Personal Research Collection',
#  'Perspectives of human evolution',
#  'Philosophy and Scientific Method',
#  'Philosophy of the Social Sciences',
#  'Physica A: Statistical Mechanics and its Applications',
#  'Physiological Zoology',
#  'Poetics',
#  'Policy & Politics',
#  'Polish Pol. Sci. YB',
#  'Political Geography',
#  'Political Oppositions in Industrialising Asia',
#  'Political Quarterly',
#  'Political Science Quarterly',
#  'Political Studies',
#  'Politics & Society',
#  'Portal: Journal of Multidisciplinary International Studies',
#  'Primate Societies',
#  'Primate societies',
#  'Primates',
#  'Proceedings of the American Philosophical Society',
#  'Proceedings of the National Academy of Sciences',
#  'Psychiatry',
#  'Psychological Bulletin',
#  'Public Culture',
#  'Public Policy Review',
#  'Quality & Quantity',
#  'Renaissance Quarterly',
#  'Research and Dialogue on Programmatic Parties and Party Systems: Case Study Reports',
#  'Research on Democracy and Society',
#  'Review of International Organizations',
#  'Review of Korean Studies',
#  'Review of Political Economy',
#  'Review of Radical Political Economics',
#  'Review of Religious Research',
#  "Revue belge de philologie et d'histoire",
#  'SPECTATOR-LONDON-WEEKLY-',
#  'SW Schmidt et alii',
#  'Science',
#  'Science Studies',
#  'Science, technology, & human values',
#  'Self-organization of complex structures: From individual to collective dynamics',
#  'Seoul: Baeksanseodang',
#  'Sex Roles',
#  'Simians, cyborgs and women: reinvention of nature',
#  'Social Communication Among Primates',
#  'Social Forces',
#  'Social Networks',
#  'Social Psychology Quarterly',
#  'Social Science Computer Review',
#  'Social Science Journal',
#  'Social Science Quarterly',
#  'Social Science Research',
#  'Social networks',
#  'Sociological Forum',
#  'Sociological Methodology',
#  'Sociological Methods & Research',
#  'Sociological Theory',
#  'Sociometry',
#  'South African Journal of Science',
#  'Southwestern Journal of Anthropology',
#  'Sozialer Sinn',
#  'Statemaking and social movements: essays in history and theory',
#  'Strategies and structures in Thai society',
#  'Strategies and structures in Thai society. Amsterdam: Anthropologisch-Sociologisch Centrum',
#  'Studies in Comparative Communism',
#  'Taiwan Journal of Democracy',
#  'Theoretical perspectives on urban politics',
#  'Theory and Society',
#  'Theory, Culture & Society',
#  'Third World Quarterly',
#  'To aid in achieving its stated purposes and objectives this GCOE program launched a journal which publishes its academic research results in academic year 2008. Adopting the first letters from the GCOE’s program title “Gender Equality and Multicultural Conviviality”, this periodical was named “GEMC journal”. Since academic year 2009, we have published two GEMC journals, English and Japanese volumes every',
#  'Trans. Richard Nice. Stanford: Stanford University Press',
#  'Transformations of kinship',
#  'Trends in Ecology & Evolution',
#  'Tulane Studies in Zoology',
#  "Unaonsaious in Culture, New YOl'k: EP Dutton",
#  'Unconscious in Culture, ed. I. Rossi',
#  'Urbana: University of Illinois Press',
#  'VRÜ Verfassung und Recht in Übersee',
#  'Virginia Magazine of History and Biography',
#  'War in the Tribal Zone',
#  'War in the tribal zone: Expanding states and indigenous warfare',
#  'War in the tribal zone: expanding states and indigenous warfare',
#  'We, the Tikopia: A Sociological Study of Kinship in Primitive Polynesia',
#  'Western Pennsylvania History: 1918-2018',
#  'Whiskey Rebellion, Past and Present Perspectives',
#  'William and Mary Quarterly',
#  'Zeitschrift für Psychologie und Physiologie der Sinnesorgane. Abt. 1. Zeitschrift für Psychologie',
#  'Zeitschrift für Tierpsychologie',
#  'Zoologica',
#  "and the same author's Toward an American Army",
#  'baboon in medical research',
#  'bulletin of mathematical biophysics',
#  'challenge of social control',
#  'challenges of intra-party democracy',
#  'formation of national states in Western Europe',
#  'formation of national states in western Europe',
#  'good society',
#  'great apes',
#  'quoted phrase appears on',
#  'sahoekwakyoyuk(social studies education)',
#  'social anthropology of Latin America: Essays in honor of Ralph Leon Beals. Los Angeles: Latin American Center, University of California',
#  'study of Election',
#  '경제와사회',
#  '대한정치학회보',
#  '사회과학 담론과 정책',
#  '사회과학연구',
#  '세계헌법연구',
#  '아시아여성연구',
#  '아태연구',
#  '의정논총',
#  '의정연구',
#  '이화젠더법학',
#  '정치정보연구',
#  '지방정부연구',
#  '한국동북아논총',
#  '한국로고스경영학회 학술발표대회논문집',
#  '한국수사학회 학술대회',
#  '한국심리학회지: 문화 및 사회문제',
#  '한국언론학보',
#  '한국정당학회보',
#  '한국정책학회 추계학술발표논문집',
#  '한국정치연구',
#  '한국정치연구 (Journal of Korean Politics)',
#  '한국정치학회보',
#  '한국지방자치연구',
#  '한국지방자치학회보',
#  '한국지방정부학회 학술대회자료집',
#  '한국행정논집']

# %% [markdown]
# # Keywords - Clean & Disambiguate
